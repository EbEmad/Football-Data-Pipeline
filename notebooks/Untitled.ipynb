# %%
import pandas as pd

# %%
data = {
    "FirstName": ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah", "Ivy", "Jack"],
    "LastName": ["Smith", "Johnson", "Brown", "Taylor", "Anderson", "Thomas", "Martinez", "Harris", "Clark", "Lewis"]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   FirstName  LastName
# 0     Alice     Smith
# 1       Bob   Johnson
# 2   Charlie     Brown
# 3     David    Taylor
# 4       Eve  Anderson
# 5     Frank    Thomas
# 6     Grace  Martinez
# 7    Hannah    Harris
# 8       Ivy     Clark
# 9      Jack     Lewis

# %%
df['fullname']=df['FirstName']+' '+df['LastName']

# %%
df
# Out:
#   FirstName  LastName        fullname
# 0     Alice     Smith     Alice Smith
# 1       Bob   Johnson     Bob Johnson
# 2   Charlie     Brown   Charlie Brown
# 3     David    Taylor    David Taylor
# 4       Eve  Anderson    Eve Anderson
# 5     Frank    Thomas    Frank Thomas
# 6     Grace  Martinez  Grace Martinez
# 7    Hannah    Harris   Hannah Harris
# 8       Ivy     Clark       Ivy Clark
# 9      Jack     Lewis      Jack Lewis

# %%
del df['fulname']

# %%
df.drop(columns=['fullname'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.drop(columns=['fullname'],inplace=True)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df
# Out:
#   FirstName  LastName
# 0     Alice     Smith
# 1       Bob   Johnson
# 2   Charlie     Brown
# 3     David    Taylor
# 4       Eve  Anderson
# 5     Frank    Thomas
# 6     Grace  Martinez
# 7    Hannah    Harris
# 8       Ivy     Clark
# 9      Jack     Lewis

# %%
df['fullname'].str.split(' ',expand=True)
# Out:
#          0         1
# 0    Alice     Smith
# 1      Bob   Johnson
# 2  Charlie     Brown
# 3    David    Taylor
# 4      Eve  Anderson
# 5    Frank    Thomas
# 6    Grace  Martinez
# 7   Hannah    Harris
# 8      Ivy     Clark
# 9     Jack     Lewis

# %%
df[['f1','f2']]=df['fullname'].str.split(' ',expand=True)

# %%
df
# Out:
#   FirstName  LastName        fullname       f1        f2
# 0     Alice     Smith     Alice Smith    Alice     Smith
# 1       Bob   Johnson     Bob Johnson      Bob   Johnson
# 2   Charlie     Brown   Charlie Brown  Charlie     Brown
# 3     David    Taylor    David Taylor    David    Taylor
# 4       Eve  Anderson    Eve Anderson      Eve  Anderson
# 5     Frank    Thomas    Frank Thomas    Frank    Thomas
# 6     Grace  Martinez  Grace Martinez    Grace  Martinez
# 7    Hannah    Harris   Hannah Harris   Hannah    Harris
# 8       Ivy     Clark       Ivy Clark      Ivy     Clark
# 9      Jack     Lewis      Jack Lewis     Jack     Lewis

# %%
df.append({'f1':'hema'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_112/1866983624.py in ?()
# ----> 1 df.append({'f1':'hema'},ignore_index=True)
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df
# Out:
#   FirstName  LastName        fullname       f1        f2
# 0     Alice     Smith     Alice Smith    Alice     Smith
# 1       Bob   Johnson     Bob Johnson      Bob   Johnson
# 2   Charlie     Brown   Charlie Brown  Charlie     Brown
# 3     David    Taylor    David Taylor    David    Taylor
# 4       Eve  Anderson    Eve Anderson      Eve  Anderson
# 5     Frank    Thomas    Frank Thomas    Frank    Thomas
# 6     Grace  Martinez  Grace Martinez    Grace  Martinez
# 7    Hannah    Harris   Hannah Harris   Hannah    Harris
# 8       Ivy     Clark       Ivy Clark      Ivy     Clark
# 9      Jack     Lewis      Jack Lewis     Jack     Lewis

# %%
df.drop(index=9)
# Out:
#   FirstName  LastName        fullname       f1        f2
# 0     Alice     Smith     Alice Smith    Alice     Smith
# 1       Bob   Johnson     Bob Johnson      Bob   Johnson
# 2   Charlie     Brown   Charlie Brown  Charlie     Brown
# 3     David    Taylor    David Taylor    David    Taylor
# 4       Eve  Anderson    Eve Anderson      Eve  Anderson
# 5     Frank    Thomas    Frank Thomas    Frank    Thomas
# 6     Grace  Martinez  Grace Martinez    Grace  Martinez
# 7    Hannah    Harris   Hannah Harris   Hannah    Harris
# 8       Ivy     Clark       Ivy Clark      Ivy     Clark

# %%
df
# Out:
#   FirstName  LastName        fullname       f1        f2
# 0     Alice     Smith     Alice Smith    Alice     Smith
# 1       Bob   Johnson     Bob Johnson      Bob   Johnson
# 2   Charlie     Brown   Charlie Brown  Charlie     Brown
# 3     David    Taylor    David Taylor    David    Taylor
# 4       Eve  Anderson    Eve Anderson      Eve  Anderson
# 5     Frank    Thomas    Frank Thomas    Frank    Thomas
# 6     Grace  Martinez  Grace Martinez    Grace  Martinez
# 7    Hannah    Harris   Hannah Harris   Hannah    Harris
# 8       Ivy     Clark       Ivy Clark      Ivy     Clark
# 9      Jack     Lewis      Jack Lewis     Jack     Lewis

# %%
df.dop(index=df[])
